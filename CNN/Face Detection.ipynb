# %% [markdown]
# ## 使用CV2

# %%
import cv2

# %% [markdown]
# ## 检视图片

# %%
# %ls 'test/'
# Out:
# u=1253325009,3060576234&fm=27&gp=0.jpg  u=317120065,604945478&fm=27&gp=0.jpg
# u=1272727955,2808456323&fm=27&gp=0.jpg  u=3255906725,2565409217&fm=27&gp=0.jpg
# u=1307243152,511797106&fm=27&gp=0.jpg   u=3292007549,575308843&fm=27&gp=0.jpg
# u=1368851336,3679651308&fm=27&gp=0.jpg  u=3428120747,2438473576&fm=27&gp=0.jpg
# u=1403507792,1607048127&fm=27&gp=0.jpg  u=348496764,168513804&fm=27&gp=0.jpg
# u=1975322317,4293290386&fm=27&gp=0.jpg  u=3489619384,2530103060&fm=27&gp=0.jpg
# u=2018888074,3946345716&fm=27&gp=0.jpg  u=3503469303,3613204703&fm=27&gp=0.jpg
# u=2280672696,21687506&fm=27&gp=0.jpg    u=3568548935,2837212673&fm=27&gp=0.jpg
# u=2435202288,812889936&fm=27&gp=0.jpg   u=3720685320,3325994284&fm=27&gp=0.jpg
# u=2489421844,1036451924&fm=27&gp=0.jpg  u=3871813154,1041061679&fm=27&gp=0.jpg
# u=2566339983,85740535&fm=27&gp=0.jpg    u=4037706002,51510812&fm=27&gp=0.jpg
# u=2643084993,2693459637&fm=27&gp=0.jpg  u=756781385,86675949&fm=27&gp=0.jpg
# u=283702151,3548867395&fm=27&gp=0.jpg   u=78277265,662571810&fm=27&gp=0.jpg
# u=3075999443,1685987041&fm=27&gp=0.jpg  u=914577625,1032683163&fm=27&gp=0.jpg
# u=309115571,489481079&fm=27&gp=0.jpg    u=956705703,451819782&fm=27&gp=0.jpg

# %%
from PIL import Image
Image.open('test/u=1253325009,3060576234&fm=27&gp=0.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x821 at 0x108BD2470>

# %% [markdown]
# ## 使用CV2侦测脸部

# %%
import cv2 as cv
img = cv.imread('test/u=1253325009,3060576234&fm=27&gp=0.jpg')

# %%
img.shape
# Out:
# (821, 500, 3)

# %%
face_cascade = cv.CascadeClassifier('/Users/davidchiu/.pyenv/versions/3.6.2/lib/python3.6/site-packages/cv2/data/haarcascade_frontalface_default.xml')
faces = face_cascade.detectMultiScale(img, 1.3, 5)

# %%
for (x,y,w,h) in faces:
    print(x,y,w,h)
# Out:
# 198 105 231 231

# %%
im = Image.open('test/u=1253325009,3060576234&fm=27&gp=0.jpg')
#im

# %% [markdown]
# ## 取得脸部特征资讯

# %%
x,y,w,h = faces[0]

# %%
crpim = im.crop((x,y, x + w, y + h)).resize((64,64))

# %%
crpim
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x1090ED748>

# %% [markdown]
# ## 使用OpenCV 撷取人脸

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
face_cascade = cv.CascadeClassifier('/Users/davidchiu/.pyenv/versions/3.6.2/lib/python3.6/site-packages/cv2/data/haarcascade_frontalface_default.xml')
from PIL import Image

def extractFace(filename, src_dir, dest_dir):
    img = cv.imread(src_dir + filename)
    faces = face_cascade.detectMultiScale(img, 1.3, 5)
    im = Image.open(src_dir + filename)
    for (x,y,w,h) in faces:
        box = (x, y, x+w, y+h)
        crpim = im.crop(box).resize((64,64))
        crpim.save(dest_dir + filename)

# %% [markdown]
# ## 检视脸部图片

# %%
import os
os.mkdir('test_dest')

# %%
for filename in os.listdir('test/'):
    #print(filename)
    extractFace(filename, 'test/', 'test_dest/')

# %%
# %ls 'test_dest/'
# Out:
# u=1253325009,3060576234&fm=27&gp=0.jpg  u=3255906725,2565409217&fm=27&gp=0.jpg
# u=1272727955,2808456323&fm=27&gp=0.jpg  u=3292007549,575308843&fm=27&gp=0.jpg
# u=1307243152,511797106&fm=27&gp=0.jpg   u=3428120747,2438473576&fm=27&gp=0.jpg
# u=1368851336,3679651308&fm=27&gp=0.jpg  u=348496764,168513804&fm=27&gp=0.jpg
# u=1403507792,1607048127&fm=27&gp=0.jpg  u=3489619384,2530103060&fm=27&gp=0.jpg
# u=1975322317,4293290386&fm=27&gp=0.jpg  u=3503469303,3613204703&fm=27&gp=0.jpg
# u=2280672696,21687506&fm=27&gp=0.jpg    u=3720685320,3325994284&fm=27&gp=0.jpg
# u=2435202288,812889936&fm=27&gp=0.jpg   u=3871813154,1041061679&fm=27&gp=0.jpg
# u=2566339983,85740535&fm=27&gp=0.jpg    u=4037706002,51510812&fm=27&gp=0.jpg
# u=2643084993,2693459637&fm=27&gp=0.jpg  u=756781385,86675949&fm=27&gp=0.jpg
# u=283702151,3548867395&fm=27&gp=0.jpg   u=78277265,662571810&fm=27&gp=0.jpg
# u=309115571,489481079&fm=27&gp=0.jpg    u=914577625,1032683163&fm=27&gp=0.jpg
# u=317120065,604945478&fm=27&gp=0.jpg    u=956705703,451819782&fm=27&gp=0.jpg

# %%
Image.open('test_dest/u=1253325009,3060576234&fm=27&gp=0.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=64x64 at 0x1090F3A90>
